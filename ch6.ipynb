# %%
import numpy as np
import pandas as pd

df = pd.read_csv('https://archive.ics.uci.edu/ml/'
                 'machine-learning-databases'
                 '/breast-cancer-wisconsin/wdbc.data',header=None)
df.head() # 1열의 특성은 진단결과(M은 악성. B는 양성)

# %%
from sklearn.preprocessing import LabelEncoder

X = df.loc[:, 2:].values
y = df.loc[:, 1].values

le=LabelEncoder() # 클레스 레이블을 알파벳 순서대로 정렬('B'가 0 'M'이 1): 문자에서 정수로 변환
y=le.fit_transform(y)
le.classes_

# %%
le.transform(['M', 'B'])
array([1,0])
